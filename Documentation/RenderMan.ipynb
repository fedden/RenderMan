# %% [markdown]
# #A RenderMan Example
#
# Here is how you can use the RenderMan library to get data from synths. I'll be using [Dexed](https://asb2m10.github.io/dexed/) as the plugin, which is a close model of the Yamaha DX7.
#
# ![](https://i.ytimg.com/vi/bdd_yOCmRUw/hqdefault.jpg)
#
# First, we set up the two objects which render and create synth parameters respectively from the classes 'RenderEngine' and 'PatchGenerator'. I am working on Linux and therefore VSTs are shared objects - .so files. At the end I print out the plugins parameters so it is easy to see which parameter does what at which index.

# %%
import renderman as rm

# Important settings. These are good general ones.
sampleRate = 44100
bufferSize = 512
fftSize = 512

# This will host a VST. It will render the features and audio we need.
engine = rm.RenderEngine(sampleRate, bufferSize, fftSize)

# Load the VST into the RenderEngine.
path = "/home/tollie/Development/vsts/dexed/Builds/Linux/build/Dexed.so"
engine.load_plugin(path)

# Create a patch generator. We can initialise it to generate the correct
# patches for a given synth by passing it a RenderEngine which has
# loaded a instance of the synthesiser. 
generator = rm.PatchGenerator(engine)

# We can also get a string of information about the
# available parameters.
print engine.get_plugin_parameters_description()
# Out:
# * Index:   0
#   Name:  Cutoff
# * Index:   1
#   Name:  Resonance
# * Index:   2
#   Name:  Output
# * Index:   3
#   Name:  MASTER TUNE ADJ
# * Index:   4
#   Name:  ALGORITHM
# * Index:   5
#   Name:  FEEDBACK
# * Index:   6
#   Name:  OSC KEY SYNC
# * Index:   7
#   Name:  LFO SPEED
# * Index:   8
#   Name:  LFO DELAY
# * Index:   9
#   Name:  LFO PM DEPTH
# * Index:  10
#   Name:  LFO AM DEPTH
# * Index:  11
#   Name:  LFO KEY SYNC
# * Index:  12
#   Name:  LFO WAVE
# * Index:  13
#   Name:  MIDDLE C
# * Index:  14
#   Name:  P MODE SENS.
# * Index:  15
#   Name:  PITCH EG RATE 1
# * Index:  16
#   Name:  PITCH EG RATE 2
# * Index:  17
#   Name:  PITCH EG RATE 3
# * Index:  18
#   Name:  PITCH EG RATE 4
# * Index:  19
#   Name:  PITCH EG LEVEL
# * Index:  20
#   Name:  PITCH EG LEVEL
# * Index:  21
#   Name:  PITCH EG LEVEL
# * Index:  22
#   Name:  PITCH EG LEVEL
# * Index:  23
#   Name:  OP1 EG RATE 1
# * Index:  24
#   Name:  OP1 EG RATE 2
# * Index:  25
#   Name:  OP1 EG RATE 3
# * Index:  26
#   Name:  OP1 EG RATE 4
# * Index:  27
#   Name:  OP1 EG LEVEL 1
# * Index:  28
#   Name:  OP1 EG LEVEL 2
# * Index:  29
#   Name:  OP1 EG LEVEL 3
# * Index:  30
#   Name:  OP1 EG LEVEL 4
# * Index:  31
#   Name:  OP1 OUTPUT LEVE
# * Index:  32
#   Name:  OP1 MODE
# * Index:  33
#   Name:  OP1 F COARSE
# * Index:  34
#   Name:  OP1 F FINE
# * Index:  35
#   Name:  OP1 OSC DETUNE
# * Index:  36
#   Name:  OP1 BREAK POINT
# * Index:  37
#   Name:  OP1 L SCALE DEP
# * Index:  38
#   Name:  OP1 R SCALE DEP
# * Index:  39
#   Name:  OP1 L KEY SCALE
# * Index:  40
#   Name:  OP1 R KEY SCALE
# * Index:  41
#   Name:  OP1 RATE SCALIN
# * Index:  42
#   Name:  OP1 A MOD SENS.
# * Index:  43
#   Name:  OP1 KEY VELOCIT
# * Index:  44
#   Name:  OP1 SWITCH
# * Index:  45
#   Name:  OP2 EG RATE 1
# * Index:  46
#   Name:  OP2 EG RATE 2
# * Index:  47
#   Name:  OP2 EG RATE 3
# * Index:  48
#   Name:  OP2 EG RATE 4
# * Index:  49
#   Name:  OP2 EG LEVEL 1
# * Index:  50
#   Name:  OP2 EG LEVEL 2
# * Index:  51
#   Name:  OP2 EG LEVEL 3
# * Index:  52
#   Name:  OP2 EG LEVEL 4
# * Index:  53
#   Name:  OP2 OUTPUT LEVE
# * Index:  54
#   Name:  OP2 MODE
# * Index:  55
#   Name:  OP2 F COARSE
# * Index:  56
#   Name:  OP2 F FINE
# * Index:  57
#   Name:  OP2 OSC DETUNE
# * Index:  58
#   Name:  OP2 BREAK POINT
# * Index:  59
#   Name:  OP2 L SCALE DEP
# * Index:  60
#   Name:  OP2 R SCALE DEP
# * Index:  61
#   Name:  OP2 L KEY SCALE
# * Index:  62
#   Name:  OP2 R KEY SCALE
# * Index:  63
#   Name:  OP2 RATE SCALIN
# * Index:  64
#   Name:  OP2 A MOD SENS.
# * Index:  65
#   Name:  OP2 KEY VELOCIT
# * Index:  66
#   Name:  OP2 SWITCH
# * Index:  67
#   Name:  OP3 EG RATE 1
# * Index:  68
#   Name:  OP3 EG RATE 2
# * Index:  69
#   Name:  OP3 EG RATE 3
# * Index:  70
#   Name:  OP3 EG RATE 4
# * Index:  71
#   Name:  OP3 EG LEVEL 1
# * Index:  72
#   Name:  OP3 EG LEVEL 2
# * Index:  73
#   Name:  OP3 EG LEVEL 3
# * Index:  74
#   Name:  OP3 EG LEVEL 4
# * Index:  75
#   Name:  OP3 OUTPUT LEVE
# * Index:  76
#   Name:  OP3 MODE
# * Index:  77
#   Name:  OP3 F COARSE
# * Index:  78
#   Name:  OP3 F FINE
# * Index:  79
#   Name:  OP3 OSC DETUNE
# * Index:  80
#   Name:  OP3 BREAK POINT
# * Index:  81
#   Name:  OP3 L SCALE DEP
# * Index:  82
#   Name:  OP3 R SCALE DEP
# * Index:  83
#   Name:  OP3 L KEY SCALE
# * Index:  84
#   Name:  OP3 R KEY SCALE
# * Index:  85
#   Name:  OP3 RATE SCALIN
# * Index:  86
#   Name:  OP3 A MOD SENS.
# * Index:  87
#   Name:  OP3 KEY VELOCIT
# * Index:  88
#   Name:  OP3 SWITCH
# * Index:  89
#   Name:  OP4 EG RATE 1
# * Index:  90
#   Name:  OP4 EG RATE 2
# * Index:  91
#   Name:  OP4 EG RATE 3
# * Index:  92
#   Name:  OP4 EG RATE 4
# * Index:  93
#   Name:  OP4 EG LEVEL 1
# * Index:  94
#   Name:  OP4 EG LEVEL 2
# * Index:  95
#   Name:  OP4 EG LEVEL 3
# * Index:  96
#   Name:  OP4 EG LEVEL 4
# * Index:  97
#   Name:  OP4 OUTPUT LEVE
# * Index:  98
#   Name:  OP4 MODE
# * Index:  99
#   Name:  OP4 F COARSE
# * Index: 100
#   Name:  OP4 F FINE
# * Index: 101
#   Name:  OP4 OSC DETUNE
# * Index: 102
#   Name:  OP4 BREAK POINT
# * Index: 103
#   Name:  OP4 L SCALE DEP
# * Index: 104
#   Name:  OP4 R SCALE DEP
# * Index: 105
#   Name:  OP4 L KEY SCALE
# * Index: 106
#   Name:  OP4 R KEY SCALE
# * Index: 107
#   Name:  OP4 RATE SCALIN
# * Index: 108
#   Name:  OP4 A MOD SENS.
# * Index: 109
#   Name:  OP4 KEY VELOCIT
# * Index: 110
#   Name:  OP4 SWITCH
# * Index: 111
#   Name:  OP5 EG RATE 1
# * Index: 112
#   Name:  OP5 EG RATE 2
# * Index: 113
#   Name:  OP5 EG RATE 3
# * Index: 114
#   Name:  OP5 EG RATE 4
# * Index: 115
#   Name:  OP5 EG LEVEL 1
# * Index: 116
#   Name:  OP5 EG LEVEL 2
# * Index: 117
#   Name:  OP5 EG LEVEL 3
# * Index: 118
#   Name:  OP5 EG LEVEL 4
# * Index: 119
#   Name:  OP5 OUTPUT LEVE
# * Index: 120
#   Name:  OP5 MODE
# * Index: 121
#   Name:  OP5 F COARSE
# * Index: 122
#   Name:  OP5 F FINE
# * Index: 123
#   Name:  OP5 OSC DETUNE
# * Index: 124
#   Name:  OP5 BREAK POINT
# * Index: 125
#   Name:  OP5 L SCALE DEP
# * Index: 126
#   Name:  OP5 R SCALE DEP
# * Index: 127
#   Name:  OP5 L KEY SCALE
# * Index: 128
#   Name:  OP5 R KEY SCALE
# * Index: 129
#   Name:  OP5 RATE SCALIN
# * Index: 130
#   Name:  OP5 A MOD SENS.
# * Index: 131
#   Name:  OP5 KEY VELOCIT
# * Index: 132
#   Name:  OP5 SWITCH
# * Index: 133
#   Name:  OP6 EG RATE 1
# * Index: 134
#   Name:  OP6 EG RATE 2
# * Index: 135
#   Name:  OP6 EG RATE 3
# * Index: 136
#   Name:  OP6 EG RATE 4
# * Index: 137
#   Name:  OP6 EG LEVEL 1
# * Index: 138
#   Name:  OP6 EG LEVEL 2
# * Index: 139
#   Name:  OP6 EG LEVEL 3
# * Index: 140
#   Name:  OP6 EG LEVEL 4
# * Index: 141
#   Name:  OP6 OUTPUT LEVE
# * Index: 142
#   Name:  OP6 MODE
# * Index: 143
#   Name:  OP6 F COARSE
# * Index: 144
#   Name:  OP6 F FINE
# * Index: 145
#   Name:  OP6 OSC DETUNE
# * Index: 146
#   Name:  OP6 BREAK POINT
# * Index: 147
#   Name:  OP6 L SCALE DEP
# * Index: 148
#   Name:  OP6 R SCALE DEP
# * Index: 149
#   Name:  OP6 L KEY SCALE
# * Index: 150
#   Name:  OP6 R KEY SCALE
# * Index: 151
#   Name:  OP6 RATE SCALIN
# * Index: 152
#   Name:  OP6 A MOD SENS.
# * Index: 153
#   Name:  OP6 KEY VELOCIT
# * Index: 154
#   Name:  OP6 SWITCH

# %% [markdown]
# ##Rendering Patches
#
# We can render a patch by getting one from the generator, and rendering it with the engine. The archetecture of the DX7 and therefore Dexed too, needs to have any carrier operator's parameter 'EG LEVEL 4' set to 0.0 and 'EG RATE 4' to 1.0 to prevent hanging notes, its intentional - not a bug! Because we are just making random presets, I have overriden all of them because it would be too verbose in this tutorial to write logic to only set the carriers used in the set algorithm (parameter 4 - see the above output!)
#
# Overriding all the operator's level and rate parameters however completely kills the envelope - you'll probably want to experiment with all of this (or try removing the overriden parameters) if you end up trying Dexed too :)

# %%
# Get a random patch and set it.
new_patch = generator.get_random_patch()
engine.set_patch(new_patch)

# We need to override some parameters to prevent hanging notes in
# Dexed. 
overriden_parameters = [(26, 1.),  (30, 0.),  (48, 1.),  (52, 0.), 
                        (70, 1.),  (74, 0.),  (92, 1.),  (96, 0.), 
                        (114, 1.), (118, 0.), (136, 1.), (140, 0.)]

# Loop through each tuple, unpack it and override the correct
# parameter with the correct value to prevent hanging notes.
for parameter in overriden_parameters:
    index, value = parameter
    engine.override_plugin_parameter(index, value)


# Settings to play a note and extract data from the synth.
midiNote = 40
midiVelocity = 127
noteLength = 4.0
renderLength = 5.0

# Render the data. 
engine.render_patch(midiNote, midiVelocity, noteLength, renderLength)

# Get the data. Note the audio is automattically made mono, no
# matter what channel size for ease of use.
audio = engine.get_audio_frames()
mfccs = engine.get_mfcc_features()

# Get the patch and display it!
patch = engine.get_patch()

# The patch is just a list of tuples, one int for index
# and one float for the value. I've printed out the patch,
# note the overriden parameters are the correct ones!
for parameter in patch:
    
    # Unpack and print the parameter tuple.
    index, value = parameter
    print "Index: " + '{:3d}'.format(index) + " --- Value: " + str(value)
# Out:
# Index:   0 --- Value: 0.789355695248
# Index:   1 --- Value: 0.724943339825
# Index:   2 --- Value: 0.383328080177
# Index:   3 --- Value: 0.177786991
# Index:   4 --- Value: 0.435414582491
# Index:   5 --- Value: 0.958583116531
# Index:   6 --- Value: 0.500556707382
# Index:   7 --- Value: 0.691075921059
# Index:   8 --- Value: 0.612155675888
# Index:   9 --- Value: 0.666344404221
# Index:  10 --- Value: 0.429147779942
# Index:  11 --- Value: 0.0519999340177
# Index:  12 --- Value: 0.165458798409
# Index:  13 --- Value: 0.275213062763
# Index:  14 --- Value: 0.705754697323
# Index:  15 --- Value: 0.164393007755
# Index:  16 --- Value: 0.839564442635
# Index:  17 --- Value: 0.446140766144
# Index:  18 --- Value: 0.394685328007
# Index:  19 --- Value: 0.423067480326
# Index:  20 --- Value: 0.34467497468
# Index:  21 --- Value: 0.310785889626
# Index:  22 --- Value: 0.0334010720253
# Index:  23 --- Value: 0.11231828481
# Index:  24 --- Value: 0.915599405766
# Index:  25 --- Value: 0.598431944847
# Index:  26 --- Value: 1.0
# Index:  27 --- Value: 0.256284743547
# Index:  28 --- Value: 0.197577103972
# Index:  29 --- Value: 0.551307380199
# Index:  30 --- Value: 0.0
# Index:  31 --- Value: 0.431208908558
# Index:  32 --- Value: 0.000915195152629
# Index:  33 --- Value: 0.709108769894
# Index:  34 --- Value: 0.258923411369
# Index:  35 --- Value: 0.461588919163
# Index:  36 --- Value: 0.234619811177
# Index:  37 --- Value: 0.24120888114
# Index:  38 --- Value: 0.681348800659
# Index:  39 --- Value: 0.586806476116
# Index:  40 --- Value: 0.480665743351
# Index:  41 --- Value: 0.574038505554
# Index:  42 --- Value: 0.496708601713
# Index:  43 --- Value: 0.958743810654
# Index:  44 --- Value: 0.513234734535
# Index:  45 --- Value: 0.490505576134
# Index:  46 --- Value: 0.813071131706
# Index:  47 --- Value: 0.221633523703
# Index:  48 --- Value: 1.0
# Index:  49 --- Value: 0.028523363173
# Index:  50 --- Value: 0.0280006509274
# Index:  51 --- Value: 0.391718119383
# Index:  52 --- Value: 0.0
# Index:  53 --- Value: 0.585756838322
# Index:  54 --- Value: 0.523673534393
# Index:  55 --- Value: 0.318384319544
# Index:  56 --- Value: 0.404265135527
# Index:  57 --- Value: 0.271641671658
# Index:  58 --- Value: 0.545620143414
# Index:  59 --- Value: 0.117292970419
# Index:  60 --- Value: 0.853554964066
# Index:  61 --- Value: 0.235411256552
# Index:  62 --- Value: 0.457695305347
# Index:  63 --- Value: 0.624455988407
# Index:  64 --- Value: 0.963085055351
# Index:  65 --- Value: 0.950548350811
# Index:  66 --- Value: 0.106891013682
# Index:  67 --- Value: 0.829798936844
# Index:  68 --- Value: 0.65087556839
# Index:  69 --- Value: 0.829289674759
# Index:  70 --- Value: 1.0
# Index:  71 --- Value: 0.33230304718
# Index:  72 --- Value: 0.567824780941
# Index:  73 --- Value: 0.847933351994
# Index:  74 --- Value: 0.0
# Index:  75 --- Value: 0.0868697836995
# Index:  76 --- Value: 0.258071541786
# Index:  77 --- Value: 0.461266726255
# Index:  78 --- Value: 0.956481695175
# Index:  79 --- Value: 0.360669672489
# Index:  80 --- Value: 0.362109482288
# Index:  81 --- Value: 0.750233769417
# Index:  82 --- Value: 0.146595567465
# Index:  83 --- Value: 0.229582965374
# Index:  84 --- Value: 0.686179757118
# Index:  85 --- Value: 0.543742895126
# Index:  86 --- Value: 0.473322957754
# Index:  87 --- Value: 0.431939005852
# Index:  88 --- Value: 0.39990195632
# Index:  89 --- Value: 0.233655065298
# Index:  90 --- Value: 0.153966262937
# Index:  91 --- Value: 0.858480095863
# Index:  92 --- Value: 1.0
# Index:  93 --- Value: 0.156334236264
# Index:  94 --- Value: 0.866664588451
# Index:  95 --- Value: 0.660591065884
# Index:  96 --- Value: 0.0
# Index:  97 --- Value: 0.462884694338
# Index:  98 --- Value: 0.0197057072073
# Index:  99 --- Value: 0.492816507816
# Index: 100 --- Value: 0.630514144897
# Index: 101 --- Value: 0.274476855993
# Index: 102 --- Value: 0.147723779082
# Index: 103 --- Value: 0.906700372696
# Index: 104 --- Value: 0.701243519783
# Index: 105 --- Value: 0.452083528042
# Index: 106 --- Value: 0.119595184922
# Index: 107 --- Value: 0.952698469162
# Index: 108 --- Value: 0.135496690869
# Index: 109 --- Value: 0.104518011212
# Index: 110 --- Value: 0.00764890946448
# Index: 111 --- Value: 0.933039844036
# Index: 112 --- Value: 0.43834772706
# Index: 113 --- Value: 0.741116166115
# Index: 114 --- Value: 1.0
# Index: 115 --- Value: 0.358331084251
# Index: 116 --- Value: 0.548715770245
# Index: 117 --- Value: 0.76183950901
# Index: 118 --- Value: 0.0
# Index: 119 --- Value: 0.413419663906
# Index: 120 --- Value: 0.0860820636153
# Index: 121 --- Value: 0.408537209034
# Index: 122 --- Value: 0.225640058517
# Index: 123 --- Value: 0.750230789185
# Index: 124 --- Value: 0.986292481422
# Index: 125 --- Value: 0.324221670628
# Index: 126 --- Value: 0.68233525753
# Index: 127 --- Value: 0.020921651274
# Index: 128 --- Value: 0.877947807312
# Index: 129 --- Value: 0.987862586975
# Index: 130 --- Value: 0.930600643158
# Index: 131 --- Value: 0.146699279547
# Index: 132 --- Value: 0.823948204517
# Index: 133 --- Value: 0.590371966362
# Index: 134 --- Value: 0.941136002541
# Index: 135 --- Value: 0.0746282562613
# Index: 136 --- Value: 1.0
# Index: 137 --- Value: 0.33740863204
# Index: 138 --- Value: 0.645250082016
# Index: 139 --- Value: 0.67262005806
# Index: 140 --- Value: 0.0
# Index: 141 --- Value: 0.287937700748
# Index: 142 --- Value: 0.286156475544
# Index: 143 --- Value: 0.207484275103
# Index: 144 --- Value: 0.96526902914
# Index: 145 --- Value: 0.446001172066
# Index: 146 --- Value: 0.199334487319
# Index: 147 --- Value: 0.875097095966
# Index: 148 --- Value: 0.0809803009033
# Index: 149 --- Value: 0.174531280994
# Index: 150 --- Value: 0.597255945206
# Index: 151 --- Value: 0.516323506832
# Index: 152 --- Value: 0.269895672798
# Index: 153 --- Value: 0.619183003902
# Index: 154 --- Value: 0.525139331818

# %% [markdown]
# ##Visualising Audio
# We are not just limited to listening to audio, we can look at it too visually. We plot the amplitude over time by simply using matplotlib's plot function.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(audio)
plt.xlabel('Time (frame count)')

# %% [markdown]
# ##Spectrograms
# We can look at frequency over time by using specgram. The y-axis is the frequency, pass the samplerate as the 'Fs' argument to set the range correctly - remember the Nyquist frequency is half the sample rate! The X-axis is time.

# %%
plt.specgram(audio, NFFT=512, Fs=sampleRate, noverlap=256)

# Plot a spectrogram
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')

# %% [markdown]
# ##Playing The Rendered Audio
#
# If working in a notebook, IPython supplies a easy way to load a mono list of samples into a HTML audio tag. If you aren't using IPython then you can use RenderMan to write to a wav, or use a python library like librosa to write to a wav.

# %%
from IPython.display import Audio

Audio(audio, rate=sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Usage in TensorFlow
#
# TensorFlow creates graphs of operations that allows for efficient machine learning computation on either the CPU using Eigen or the GPU using CUDA and cuDNN. Whilst we can't just throw in python commands in to the TensorFlow graph, we can use RenderMan in machine learning as an op with the use of TensorFlow's [tf.py_func(func, inp, Tout)](https://www.tensorflow.org/versions/r0.9/api_docs/python/script_ops.html#py_func).
#
# TBC!!!

# %%
# import tensorflow as tf

# mfcc_feature_rows = len(mfccs[0])
# mfcc_feature_cols = len(mfccs)

# number_plugin_parameters = engine.get_plugin_parameter_size()

# pretend_model_output = tf.placeholder("float", [None,
#                                                 number_plugin_parameters])

# def actual_output(parameters):
#     engine.

# tf.sqrt(tf.reduce_mean(tf.square(tf.sub(targets, pretend_model_output))))
