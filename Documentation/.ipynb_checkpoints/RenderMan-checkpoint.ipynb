# %% [markdown]
# ##A RenderMan Example
#
# Here is how you can use the RenderMan library to get data from synths. I'll be using [Dexed](https://asb2m10.github.io/dexed/) as the plugin, which is a close model of the Yamaha DX7.
#
# ![](https://i.ytimg.com/vi/bdd_yOCmRUw/hqdefault.jpg)
#
# First, we set up the two objects which render and create synth parameters respectively from the classes 'RenderEngine' and 'PatchGenerator'. I am working on Linux and therefore VSTs are shared objects - .so files. At the end I print out the plugins parameters so it is easy to see which parameter does what at which index.

# %%
import renderman as rm

# Important settings. These are good general ones.
sampleRate = 44100
bufferSize = 512
fftSize = 512

# This will host a VST. It will render the features and audio we need.
engine = rm.RenderEngine(sampleRate, bufferSize, fftSize)

# Load the VST into the RenderEngine.
path = "/home/tollie/Development/vsts/dexed/Builds/Linux/build/Dexed.so"
engine.load_plugin(path)

# Create a patch generator. We can initialise it to generate the correct
# patches for a given synth by passing it a RenderEngine which has
# loaded a instance of the synthesiser. 
generator = rm.PatchGenerator(engine)

# We can also get a string of information about the
# available parameters.
print engine.get_plugin_parameters_description()
# Out:
# * Index:   0
#   Name:  Cutoff
# * Index:   1
#   Name:  Resonance
# * Index:   2
#   Name:  Output
# * Index:   3
#   Name:  MASTER TUNE ADJ
# * Index:   4
#   Name:  ALGORITHM
# * Index:   5
#   Name:  FEEDBACK
# * Index:   6
#   Name:  OSC KEY SYNC
# * Index:   7
#   Name:  LFO SPEED
# * Index:   8
#   Name:  LFO DELAY
# * Index:   9
#   Name:  LFO PM DEPTH
# * Index:  10
#   Name:  LFO AM DEPTH
# * Index:  11
#   Name:  LFO KEY SYNC
# * Index:  12
#   Name:  LFO WAVE
# * Index:  13
#   Name:  MIDDLE C
# * Index:  14
#   Name:  P MODE SENS.
# * Index:  15
#   Name:  PITCH EG RATE 1
# * Index:  16
#   Name:  PITCH EG RATE 2
# * Index:  17
#   Name:  PITCH EG RATE 3
# * Index:  18
#   Name:  PITCH EG RATE 4
# * Index:  19
#   Name:  PITCH EG LEVEL
# * Index:  20
#   Name:  PITCH EG LEVEL
# * Index:  21
#   Name:  PITCH EG LEVEL
# * Index:  22
#   Name:  PITCH EG LEVEL
# * Index:  23
#   Name:  OP1 EG RATE 1
# * Index:  24
#   Name:  OP1 EG RATE 2
# * Index:  25
#   Name:  OP1 EG RATE 3
# * Index:  26
#   Name:  OP1 EG RATE 4
# * Index:  27
#   Name:  OP1 EG LEVEL 1
# * Index:  28
#   Name:  OP1 EG LEVEL 2
# * Index:  29
#   Name:  OP1 EG LEVEL 3
# * Index:  30
#   Name:  OP1 EG LEVEL 4
# * Index:  31
#   Name:  OP1 OUTPUT LEVE
# * Index:  32
#   Name:  OP1 MODE
# * Index:  33
#   Name:  OP1 F COARSE
# * Index:  34
#   Name:  OP1 F FINE
# * Index:  35
#   Name:  OP1 OSC DETUNE
# * Index:  36
#   Name:  OP1 BREAK POINT
# * Index:  37
#   Name:  OP1 L SCALE DEP
# * Index:  38
#   Name:  OP1 R SCALE DEP
# * Index:  39
#   Name:  OP1 L KEY SCALE
# * Index:  40
#   Name:  OP1 R KEY SCALE
# * Index:  41
#   Name:  OP1 RATE SCALIN
# * Index:  42
#   Name:  OP1 A MOD SENS.
# * Index:  43
#   Name:  OP1 KEY VELOCIT
# * Index:  44
#   Name:  OP1 SWITCH
# * Index:  45
#   Name:  OP2 EG RATE 1
# * Index:  46
#   Name:  OP2 EG RATE 2
# * Index:  47
#   Name:  OP2 EG RATE 3
# * Index:  48
#   Name:  OP2 EG RATE 4
# * Index:  49
#   Name:  OP2 EG LEVEL 1
# * Index:  50
#   Name:  OP2 EG LEVEL 2
# * Index:  51
#   Name:  OP2 EG LEVEL 3
# * Index:  52
#   Name:  OP2 EG LEVEL 4
# * Index:  53
#   Name:  OP2 OUTPUT LEVE
# * Index:  54
#   Name:  OP2 MODE
# * Index:  55
#   Name:  OP2 F COARSE
# * Index:  56
#   Name:  OP2 F FINE
# * Index:  57
#   Name:  OP2 OSC DETUNE
# * Index:  58
#   Name:  OP2 BREAK POINT
# * Index:  59
#   Name:  OP2 L SCALE DEP
# * Index:  60
#   Name:  OP2 R SCALE DEP
# * Index:  61
#   Name:  OP2 L KEY SCALE
# * Index:  62
#   Name:  OP2 R KEY SCALE
# * Index:  63
#   Name:  OP2 RATE SCALIN
# * Index:  64
#   Name:  OP2 A MOD SENS.
# * Index:  65
#   Name:  OP2 KEY VELOCIT
# * Index:  66
#   Name:  OP2 SWITCH
# * Index:  67
#   Name:  OP3 EG RATE 1
# * Index:  68
#   Name:  OP3 EG RATE 2
# * Index:  69
#   Name:  OP3 EG RATE 3
# * Index:  70
#   Name:  OP3 EG RATE 4
# * Index:  71
#   Name:  OP3 EG LEVEL 1
# * Index:  72
#   Name:  OP3 EG LEVEL 2
# * Index:  73
#   Name:  OP3 EG LEVEL 3
# * Index:  74
#   Name:  OP3 EG LEVEL 4
# * Index:  75
#   Name:  OP3 OUTPUT LEVE
# * Index:  76
#   Name:  OP3 MODE
# * Index:  77
#   Name:  OP3 F COARSE
# * Index:  78
#   Name:  OP3 F FINE
# * Index:  79
#   Name:  OP3 OSC DETUNE
# * Index:  80
#   Name:  OP3 BREAK POINT
# * Index:  81
#   Name:  OP3 L SCALE DEP
# * Index:  82
#   Name:  OP3 R SCALE DEP
# * Index:  83
#   Name:  OP3 L KEY SCALE
# * Index:  84
#   Name:  OP3 R KEY SCALE
# * Index:  85
#   Name:  OP3 RATE SCALIN
# * Index:  86
#   Name:  OP3 A MOD SENS.
# * Index:  87
#   Name:  OP3 KEY VELOCIT
# * Index:  88
#   Name:  OP3 SWITCH
# * Index:  89
#   Name:  OP4 EG RATE 1
# * Index:  90
#   Name:  OP4 EG RATE 2
# * Index:  91
#   Name:  OP4 EG RATE 3
# * Index:  92
#   Name:  OP4 EG RATE 4
# * Index:  93
#   Name:  OP4 EG LEVEL 1
# * Index:  94
#   Name:  OP4 EG LEVEL 2
# * Index:  95
#   Name:  OP4 EG LEVEL 3
# * Index:  96
#   Name:  OP4 EG LEVEL 4
# * Index:  97
#   Name:  OP4 OUTPUT LEVE
# * Index:  98
#   Name:  OP4 MODE
# * Index:  99
#   Name:  OP4 F COARSE
# * Index: 100
#   Name:  OP4 F FINE
# * Index: 101
#   Name:  OP4 OSC DETUNE
# * Index: 102
#   Name:  OP4 BREAK POINT
# * Index: 103
#   Name:  OP4 L SCALE DEP
# * Index: 104
#   Name:  OP4 R SCALE DEP
# * Index: 105
#   Name:  OP4 L KEY SCALE
# * Index: 106
#   Name:  OP4 R KEY SCALE
# * Index: 107
#   Name:  OP4 RATE SCALIN
# * Index: 108
#   Name:  OP4 A MOD SENS.
# * Index: 109
#   Name:  OP4 KEY VELOCIT
# * Index: 110
#   Name:  OP4 SWITCH
# * Index: 111
#   Name:  OP5 EG RATE 1
# * Index: 112
#   Name:  OP5 EG RATE 2
# * Index: 113
#   Name:  OP5 EG RATE 3
# * Index: 114
#   Name:  OP5 EG RATE 4
# * Index: 115
#   Name:  OP5 EG LEVEL 1
# * Index: 116
#   Name:  OP5 EG LEVEL 2
# * Index: 117
#   Name:  OP5 EG LEVEL 3
# * Index: 118
#   Name:  OP5 EG LEVEL 4
# * Index: 119
#   Name:  OP5 OUTPUT LEVE
# * Index: 120
#   Name:  OP5 MODE
# * Index: 121
#   Name:  OP5 F COARSE
# * Index: 122
#   Name:  OP5 F FINE
# * Index: 123
#   Name:  OP5 OSC DETUNE
# * Index: 124
#   Name:  OP5 BREAK POINT
# * Index: 125
#   Name:  OP5 L SCALE DEP
# * Index: 126
#   Name:  OP5 R SCALE DEP
# * Index: 127
#   Name:  OP5 L KEY SCALE
# * Index: 128
#   Name:  OP5 R KEY SCALE
# * Index: 129
#   Name:  OP5 RATE SCALIN
# * Index: 130
#   Name:  OP5 A MOD SENS.
# * Index: 131
#   Name:  OP5 KEY VELOCIT
# * Index: 132
#   Name:  OP5 SWITCH
# * Index: 133
#   Name:  OP6 EG RATE 1
# * Index: 134
#   Name:  OP6 EG RATE 2
# * Index: 135
#   Name:  OP6 EG RATE 3
# * Index: 136
#   Name:  OP6 EG RATE 4
# * Index: 137
#   Name:  OP6 EG LEVEL 1
# * Index: 138
#   Name:  OP6 EG LEVEL 2
# * Index: 139
#   Name:  OP6 EG LEVEL 3
# * Index: 140
#   Name:  OP6 EG LEVEL 4
# * Index: 141
#   Name:  OP6 OUTPUT LEVE
# * Index: 142
#   Name:  OP6 MODE
# * Index: 143
#   Name:  OP6 F COARSE
# * Index: 144
#   Name:  OP6 F FINE
# * Index: 145
#   Name:  OP6 OSC DETUNE
# * Index: 146
#   Name:  OP6 BREAK POINT
# * Index: 147
#   Name:  OP6 L SCALE DEP
# * Index: 148
#   Name:  OP6 R SCALE DEP
# * Index: 149
#   Name:  OP6 L KEY SCALE
# * Index: 150
#   Name:  OP6 R KEY SCALE
# * Index: 151
#   Name:  OP6 RATE SCALIN
# * Index: 152
#   Name:  OP6 A MOD SENS.
# * Index: 153
#   Name:  OP6 KEY VELOCIT
# * Index: 154
#   Name:  OP6 SWITCH

# %% [markdown]
# ##Rendering Patches
#
# We can render a patch by getting one from the generator, and rendering it with the engine. The archetecture of the DX7 and therefore Dexed too, needs to have any carrier operator's parameter 'EG LEVEL 4' set to 0.0 and 'EG RATE 4' to 1.0 to prevent hanging notes, its intentional - not a bug! Because we are just making random presets, I have overriden all of them because it would be too verbose in this tutorial to write logic to only set the carriers used in the set algorithm (parameter 4 - see the above output!)
#
# Overriding all the operator's level and rate parameters however completely kills the envelope - you'll probably want to experiment with all of this (or try removing the overriden parameters) if you end up trying Dexed too :)

# %%
# Get a random patch and set it.
new_patch = generator.get_random_patch()
engine.set_patch(new_patch)

# We need to override some parameters to prevent hanging notes in
# Dexed. 
overriden_parameters = [(26, 1.),  (30, 0.),  (48, 1.),  (52, 0.), 
                        (70, 1.),  (74, 0.),  (92, 1.),  (96, 0.), 
                        (114, 1.), (118, 0.), (136, 1.), (140, 0.)]

for parameter in overriden_parameters:
    index, value = parameter
    engine.override_plugin_parameter(index, value)


# Settings to play a note and extract data from the synth.
midiNote = 40
midiVelocity = 127
noteLength = 4.0
renderLength = 5.0

# Render the data. 
engine.render_patch(midiNote, midiVelocity, noteLength, renderLength)

# Get the data.
audio = engine.get_audio_frames()
mfccs = engine.get_mfcc_features()

# Get the patch and display it!
patch = engine.get_patch()

# The patch is just a list of tuples, one int for index
# and one float for the value. I've printed out the patch,
# note the overriden parameters are the correct ones!
for parameter in patch:
    
    # Unpack and print the parameter tuple.
    index, value = parameter
    print "Index: " + '{:3d}'.format(index) + " --- Value: " + str(value)
# Out:
# Index:   0 --- Value: 0.791962623596
# Index:   1 --- Value: 0.233238056302
# Index:   2 --- Value: 0.117291375995
# Index:   3 --- Value: 0.21637584269
# Index:   4 --- Value: 0.365371733904
# Index:   5 --- Value: 0.0036451832857
# Index:   6 --- Value: 0.645531535149
# Index:   7 --- Value: 0.675559103489
# Index:   8 --- Value: 0.0172458384186
# Index:   9 --- Value: 0.494201034307
# Index:  10 --- Value: 0.65339577198
# Index:  11 --- Value: 0.230344071984
# Index:  12 --- Value: 0.0920104384422
# Index:  13 --- Value: 0.682924807072
# Index:  14 --- Value: 0.26272469759
# Index:  15 --- Value: 0.362538605928
# Index:  16 --- Value: 0.146510437131
# Index:  17 --- Value: 0.659328460693
# Index:  18 --- Value: 0.800216019154
# Index:  19 --- Value: 0.235320359468
# Index:  20 --- Value: 0.924601793289
# Index:  21 --- Value: 0.133133068681
# Index:  22 --- Value: 0.101171202958
# Index:  23 --- Value: 0.112329117954
# Index:  24 --- Value: 0.902027606964
# Index:  25 --- Value: 0.569360792637
# Index:  26 --- Value: 1.0
# Index:  27 --- Value: 0.51496899128
# Index:  28 --- Value: 0.200668275356
# Index:  29 --- Value: 0.639827430248
# Index:  30 --- Value: 0.0
# Index:  31 --- Value: 0.510362803936
# Index:  32 --- Value: 0.833717703819
# Index:  33 --- Value: 0.593807339668
# Index:  34 --- Value: 0.819411277771
# Index:  35 --- Value: 0.292834252119
# Index:  36 --- Value: 0.789725899696
# Index:  37 --- Value: 0.829212665558
# Index:  38 --- Value: 0.804801285267
# Index:  39 --- Value: 0.216816648841
# Index:  40 --- Value: 0.146747305989
# Index:  41 --- Value: 0.313130021095
# Index:  42 --- Value: 0.462891459465
# Index:  43 --- Value: 0.359978586435
# Index:  44 --- Value: 0.708123385906
# Index:  45 --- Value: 0.814773440361
# Index:  46 --- Value: 0.406825810671
# Index:  47 --- Value: 0.533775269985
# Index:  48 --- Value: 1.0
# Index:  49 --- Value: 0.418002963066
# Index:  50 --- Value: 0.284260094166
# Index:  51 --- Value: 0.749881505966
# Index:  52 --- Value: 0.0
# Index:  53 --- Value: 0.0323053151369
# Index:  54 --- Value: 0.540132582188
# Index:  55 --- Value: 0.246029511094
# Index:  56 --- Value: 0.476865381002
# Index:  57 --- Value: 0.700069308281
# Index:  58 --- Value: 0.189778730273
# Index:  59 --- Value: 0.289217323065
# Index:  60 --- Value: 0.932695806026
# Index:  61 --- Value: 0.052379399538
# Index:  62 --- Value: 0.682006061077
# Index:  63 --- Value: 0.837768912315
# Index:  64 --- Value: 0.296285718679
# Index:  65 --- Value: 0.627803206444
# Index:  66 --- Value: 0.643692374229
# Index:  67 --- Value: 0.916134357452
# Index:  68 --- Value: 0.6566182971
# Index:  69 --- Value: 0.040121473372
# Index:  70 --- Value: 1.0
# Index:  71 --- Value: 0.227954745293
# Index:  72 --- Value: 0.289409577847
# Index:  73 --- Value: 0.65002065897
# Index:  74 --- Value: 0.0
# Index:  75 --- Value: 0.0839573666453
# Index:  76 --- Value: 0.987633049488
# Index:  77 --- Value: 0.967640578747
# Index:  78 --- Value: 0.170137569308
# Index:  79 --- Value: 0.233468472958
# Index:  80 --- Value: 0.806874096394
# Index:  81 --- Value: 0.571834564209
# Index:  82 --- Value: 0.888302922249
# Index:  83 --- Value: 0.822770059109
# Index:  84 --- Value: 0.123920999467
# Index:  85 --- Value: 0.269497960806
# Index:  86 --- Value: 0.821434676647
# Index:  87 --- Value: 0.0608709976077
# Index:  88 --- Value: 0.985819220543
# Index:  89 --- Value: 0.895259141922
# Index:  90 --- Value: 0.970067679882
# Index:  91 --- Value: 0.70833170414
# Index:  92 --- Value: 1.0
# Index:  93 --- Value: 0.334669083357
# Index:  94 --- Value: 0.558095991611
# Index:  95 --- Value: 0.222906202078
# Index:  96 --- Value: 0.0
# Index:  97 --- Value: 0.514857470989
# Index:  98 --- Value: 0.489590227604
# Index:  99 --- Value: 0.907148182392
# Index: 100 --- Value: 0.889006257057
# Index: 101 --- Value: 0.583839118481
# Index: 102 --- Value: 0.305198460817
# Index: 103 --- Value: 0.362529605627
# Index: 104 --- Value: 0.206739157438
# Index: 105 --- Value: 0.581991136074
# Index: 106 --- Value: 0.645475029945
# Index: 107 --- Value: 0.120427720249
# Index: 108 --- Value: 0.252792656422
# Index: 109 --- Value: 0.169996798038
# Index: 110 --- Value: 0.865682423115
# Index: 111 --- Value: 0.0514775812626
# Index: 112 --- Value: 0.202889487147
# Index: 113 --- Value: 0.30418124795
# Index: 114 --- Value: 1.0
# Index: 115 --- Value: 0.491786122322
# Index: 116 --- Value: 0.779484331608
# Index: 117 --- Value: 0.725305199623
# Index: 118 --- Value: 0.0
# Index: 119 --- Value: 0.418372601271
# Index: 120 --- Value: 0.712635457516
# Index: 121 --- Value: 0.752358257771
# Index: 122 --- Value: 0.537610530853
# Index: 123 --- Value: 0.139391303062
# Index: 124 --- Value: 0.746134757996
# Index: 125 --- Value: 0.637256622314
# Index: 126 --- Value: 0.382229298353
# Index: 127 --- Value: 0.109035126865
# Index: 128 --- Value: 0.405162870884
# Index: 129 --- Value: 0.639308333397
# Index: 130 --- Value: 0.312885463238
# Index: 131 --- Value: 0.583870232105
# Index: 132 --- Value: 0.160178765655
# Index: 133 --- Value: 0.941464781761
# Index: 134 --- Value: 0.0213546510786
# Index: 135 --- Value: 0.842160522938
# Index: 136 --- Value: 1.0
# Index: 137 --- Value: 0.250884026289
# Index: 138 --- Value: 0.679556488991
# Index: 139 --- Value: 0.421430408955
# Index: 140 --- Value: 0.0
# Index: 141 --- Value: 0.325813770294
# Index: 142 --- Value: 0.760837435722
# Index: 143 --- Value: 0.796620428562
# Index: 144 --- Value: 0.271272480488
# Index: 145 --- Value: 0.634230971336
# Index: 146 --- Value: 0.683141767979
# Index: 147 --- Value: 0.583280801773
# Index: 148 --- Value: 0.296381652355
# Index: 149 --- Value: 0.326874226332
# Index: 150 --- Value: 0.309558033943
# Index: 151 --- Value: 0.998271763325
# Index: 152 --- Value: 0.314629822969
# Index: 153 --- Value: 0.535452604294
# Index: 154 --- Value: 0.529864549637

# %% [markdown]
# ##Visualising Audio
# We can plot the amplitude over time by simply using plot.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(audio)
plt.xlabel('Time (frame count)')

# %% [markdown]
# ##Spectrograms
# We can look at frequency over time by using specgram. The y-axis is the frequency, pass the samplerate as the 'Fs' argument to set the range correctly - remember the Nyquist frequency is half the sample rate! The X-axis is time.

# %%
plt.specgram(audio, NFFT=512, Fs=sampleRate, noverlap=256)

# Plot a spectrogram
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')

# %% [markdown]
# ##Playing The Rendered Audio
#
# If working in a notebook, IPython supplies a easy way to load a mono list of samples into a HTML audio tag. If you aren't using IPython then you can use RenderMan to write to a wav, or use a python library like librosa to write to a wav.

# %%
from IPython.display import Audio

Audio(audio, rate=sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Usage in TensorFlow
#
# TensorFlow creates graphs of operations that allows for efficient machine learning computation on either the CPU using Eigen or the GPU using CUDA and cuDNN. Whilst we can't just throw in python commands in to the TensorFlow graph, we can use RenderMan in machine learning as an op with the use of TensorFlow's [tf.py_func(func, inp, Tout)](https://www.tensorflow.org/versions/r0.9/api_docs/python/script_ops.html#py_func).
